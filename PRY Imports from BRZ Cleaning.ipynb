# %%
import os
import pandas as pd

# %%
os.getcwd()
# Out:
# 'c:\\Users\\bfran\\Ironhack\\Week 3\\Project'

# %%
# Saves as df data pulled from UN Comtrade Database
df = pd.read_csv("PRY Imports from BRZ.csv", encoding='unicode_escape')

# %%
# Displays dataframe
df
# Out:
#      TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 0           C        A     20230101     2023        52    2023           600
# 1           C        A     20230101     2023        52    2023           600
# 2           C        A     20230101     2023        52    2023           600
# 3           C        A     20230101     2023        52    2023           600
# 4           C        A     20230101     2023        52    2023           600
# ...       ...      ...          ...      ...       ...     ...           ...
# 4372        C        A     20230101     2023        52    2023           600
# 4373        C        A     20230101     2023        52    2023           600
# 4374        C        A     20230101     2023        52    2023           600
# 4375        C        A     20230101     2023        52    2023           600
# 4376        C        A     20230101     2023        52    2023           600
#
#      ReporterISO ReporterDesc FlowCode  ... IsNetWgtEstimated  GrossWgt  \
# 0            PRY     Paraguay        M  ...             False         0
# 1            PRY     Paraguay        M  ...             False         0
# 2            PRY     Paraguay        M  ...             False         0
# 3            PRY     Paraguay        M  ...             False         0
# 4            PRY     Paraguay        M  ...             False         0
# ...          ...          ...      ...  ...               ...       ...
# 4372         PRY     Paraguay        M  ...             False         0
# 4373         PRY     Paraguay        M  ...             False         0
# 4374         PRY     Paraguay        M  ...             False         0
# 4375         PRY     Paraguay        M  ...             False         0
# 4376         PRY     Paraguay        M  ...              True         0
#
#      IsGrossWgtEstimated      Cifvalue      Fobvalue  PrimaryValue  \
# 0                  False  1.312960e+07  1.243655e+07  1.312960e+07
# 1                  False  7.778350e+04  7.508065e+04  7.778350e+04
# 2                  False  7.778350e+04  7.508065e+04  7.778350e+04
# 3                  False  1.692392e+05  1.638012e+05  1.692392e+05
# 4                  False  1.692392e+05  1.638012e+05  1.692392e+05
# ...                  ...           ...           ...           ...
# 4372               False  3.929800e+04  3.880272e+04  3.929800e+04
# 4373               False  1.693100e+02  1.672000e+02  1.693100e+02
# 4374               False  4.483780e+03  3.667110e+03  4.483780e+03
# 4375               False  7.069253e+05  6.705306e+05  7.069253e+05
# 4376               False  3.930499e+09  3.720551e+09  3.930499e+09
#
#      LegacyEstimationFlag IsReported IsAggregate  Unnamed: 47
# 0                       0      False        True          NaN
# 1                       0      False        True          NaN
# 2                       0      False        True          NaN
# 3                       2      False        True          NaN
# 4                       2      False        True          NaN
# ...                   ...        ...         ...          ...
# 4372                    0      False        True          NaN
# 4373                    0      False        True          NaN
# 4374                    0      False        True          NaN
# 4375                    0      False        True          NaN
# 4376                    4      False        True          NaN
#
# [4377 rows x 48 columns]

# %%
# Defines useful columns to keep
columns_to_keep = ['RefYear','ReporterDesc','FlowDesc','PartnerDesc','CmdCode','CmdDesc','AggrLevel','QtyUnitAbbr','Qty','NetWgt','Cifvalue','Fobvalue']

# %%
# Saves the dataframe with only those columns that have useful data
df = df.loc[:,columns_to_keep]

# %%
# Saves the dataframe keeping only those rows with an HS level of 6 digits
df = df[df['AggrLevel'] == 6]

# %%
# Removes the now useless AggrLevel column
df = df.drop(columns= 'AggrLevel')

# %%
# Renames columns in order to provide clarity and to make merging datasets easier later
df.rename(columns = {'RefYear':'year',
          'ReporterDesc': 'reporter',
          'FlowDesc':'trade_flow',
          'PartnerDesc':'partner',
          'CmdCode':'hs_code',
          'CmdDesc':'commodity',
          'QtyUnitAbbr':'unit_type',
          'Qty':'quantity',
          'NetWgt':'net_weight',
          'Cifvalue':'cif_value',
          'Fobvalue':'fob_value'},
          inplace=True)

# Displays new dataframe with new column names
df
# Out:
#       year  reporter trade_flow partner hs_code  \
# 2     2023  Paraguay     Import  Brazil  010121
# 4     2023  Paraguay     Import  Brazil  010221
# 6     2023  Paraguay     Import  Brazil  010310
# 7     2023  Paraguay     Import  Brazil  010392
# 9     2023  Paraguay     Import  Brazil  010511
# ...    ...       ...        ...     ...     ...
# 4369  2023  Paraguay     Import  Brazil  962000
# 4372  2023  Paraguay     Import  Brazil  970121
# 4373  2023  Paraguay     Import  Brazil  970191
# 4374  2023  Paraguay     Import  Brazil  970199
# 4375  2023  Paraguay     Import  Brazil  999999
#
#                                               commodity unit_type  quantity  \
# 2              Horses; live, pure-bred breeding animals       NaN     0.000
# 4              Cattle; live, pure-bred breeding animals         u    79.701
# 6               Swine; live, pure-bred breeding animals       NaN     0.000
# 7     Swine; live, other than pure-bred breeding ani...         u  2690.914
# 9     Poultry; live, fowls of the species Gallus dom...       NaN     0.000
# ...                                                 ...       ...       ...
# 4369     Monopods, bipods, tripods and similar articles        kg    17.320
# 4372  Paintings, drawings and pastels; executed enti...       NaN     0.000
# 4373  Paintings, drawings and pastels; executed enti...       NaN     0.000
# 4374  Artwork; other than paintings, drawings, paste...        kg    66.600
# 4375        Commodities not specified according to kind       NaN     0.000
#
#       net_weight    cif_value    fob_value
# 2        8200.00     77783.50     75080.65
# 4       10925.00    169239.20    163801.19
# 6       55587.00    697124.31    649040.72
# 7       79650.00    655794.51    579105.90
# 9      667138.80  11529662.15  10969520.83
# ...          ...          ...          ...
# 4369       17.32      1799.50      1779.60
# 4372     2709.18     39298.00     38802.72
# 4373       32.00       169.31       167.20
# 4374       66.60      4483.78      3667.11
# 4375        0.00    706925.27    670530.56
#
# [3299 rows x 11 columns]

# %%
# Checks values of unit types to be updated
df['unit_type'].value_counts()
# Out:
# unit_type
# kg    2406
# u      341
# m²      22
# l       21
# 2u      18
# m³       8
# Name: count, dtype: int64

# %%
# Creates a dictionary with old unit_type values and the values we want to change them to. 
# Updated values provide clarity in regards to unit types
replace_dict = {
    '2u':'pairs_of_units',
    'l':'liters',
    'm²':'square_meters',
    'm³':'cubic_meters',
    'u':'units'
}

# %%
# Actually updates the unit types. 
df['unit_type'] = df['unit_type'].replace(replace_dict)

# %%
# Displays modified values in unit_types
df['unit_type'].value_counts()
# Out:
# unit_type
# kg                2406
# units              341
# square_meters       22
# liters              21
# pairs_of_units      18
# cubic_meters         8
# Name: count, dtype: int64

# %%
# Changes value in trade_flow column from Import to imported_from to provide clarity of trade flows.
df['trade_flow']=df['trade_flow'].replace('Import','imported_from')

# %%
df
# Out:
#       year  reporter     trade_flow partner hs_code  \
# 2     2023  Paraguay  imported_from  Brazil  010121
# 4     2023  Paraguay  imported_from  Brazil  010221
# 6     2023  Paraguay  imported_from  Brazil  010310
# 7     2023  Paraguay  imported_from  Brazil  010392
# 9     2023  Paraguay  imported_from  Brazil  010511
# ...    ...       ...            ...     ...     ...
# 4369  2023  Paraguay  imported_from  Brazil  962000
# 4372  2023  Paraguay  imported_from  Brazil  970121
# 4373  2023  Paraguay  imported_from  Brazil  970191
# 4374  2023  Paraguay  imported_from  Brazil  970199
# 4375  2023  Paraguay  imported_from  Brazil  999999
#
#                                               commodity unit_type  quantity  \
# 2              Horses; live, pure-bred breeding animals       NaN     0.000
# 4              Cattle; live, pure-bred breeding animals     units    79.701
# 6               Swine; live, pure-bred breeding animals       NaN     0.000
# 7     Swine; live, other than pure-bred breeding ani...     units  2690.914
# 9     Poultry; live, fowls of the species Gallus dom...       NaN     0.000
# ...                                                 ...       ...       ...
# 4369     Monopods, bipods, tripods and similar articles        kg    17.320
# 4372  Paintings, drawings and pastels; executed enti...       NaN     0.000
# 4373  Paintings, drawings and pastels; executed enti...       NaN     0.000
# 4374  Artwork; other than paintings, drawings, paste...        kg    66.600
# 4375        Commodities not specified according to kind       NaN     0.000
#
#       net_weight    cif_value    fob_value
# 2        8200.00     77783.50     75080.65
# 4       10925.00    169239.20    163801.19
# 6       55587.00    697124.31    649040.72
# 7       79650.00    655794.51    579105.90
# 9      667138.80  11529662.15  10969520.83
# ...          ...          ...          ...
# 4369       17.32      1799.50      1779.60
# 4372     2709.18     39298.00     38802.72
# 4373       32.00       169.31       167.20
# 4374       66.60      4483.78      3667.11
# 4375        0.00    706925.27    670530.56
#
# [3299 rows x 11 columns]

# %%
# Next step is dealing with NaNs - leave that for tomorrow
