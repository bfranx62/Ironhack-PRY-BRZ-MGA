# %%
#importing packages we need
import pandas as pd
import os 
import numpy as np

# %%
#gets current working directory 
os.getcwd()
# Out:
# 'c:\\Users\\wilfe\\OneDrive\\Documents\\GitHub\\Ironhack-PRY-BRZ-MGA'

# %%
#saves as df previously created mx_compare2 file 
df = pd.read_csv('mx_compare2.csv')

# %%
df
# Out:
#       hs_code      br_x_q br_x_unit      py_m_q py_m_unit  br_x_nt_wgt  \
# 0       10310       641.0     units        0.00        NR      58244.0
# 1       10392       904.0     units     2690.91     units      79649.0
# 2       10511  13417432.0     units        0.00        NR     642645.0
# 3       20130   3428542.0        kg  3828180.00        kg    3428542.0
# 4       20220   1822983.0        kg  1845790.00        kg    1822983.0
# ...       ...         ...       ...         ...       ...          ...
# 3056   910211         2.0     units        0.00        NR          1.0
# 3057   910229       100.0     units        0.00        NR          3.0
# 3058   910521        10.0     units        0.00        NR          4.0
# 3059   950632        22.0     units        0.00        NR         14.0
# 3060   961320        17.0     units        0.00        NR          2.0
#
#       py_m_nt_wgt  br_x_value  itic_rate  applied_tariff  adj_x_value  \
# ...

# %%
hs_classification = pd.read_csv('brz_app_tariffs.csv')

# %%
hs_classification.drop(['reporter','year','applied_tariff'], axis=1, inplace=True)

# %%
df = df.merge(hs_classification, on='hs_code', how='inner')

# %%
df
# Out:
#       hs_code  br_x_q br_x_unit   py_m_q py_m_unit  br_x_nt_wgt  py_m_nt_wgt  \
# 0       10310   641.0     units     0.00        NR      58244.0      55587.0
# 1       10310   641.0     units     0.00        NR      58244.0      55587.0
# 2       10310   641.0     units     0.00        NR      58244.0      55587.0
# 3       10392   904.0     units  2690.91     units      79649.0      79650.0
# 4       10392   904.0     units  2690.91     units      79649.0      79650.0
# ...       ...     ...       ...      ...       ...          ...          ...
# 9178   950632    22.0     units     0.00        NR         14.0          0.0
# 9179   950632    22.0     units     0.00        NR         14.0          0.0
# 9180   961320    17.0     units     0.00        NR          2.0          0.0
# 9181   961320    17.0     units     0.00        NR          2.0          0.0
# 9182   961320    17.0     units     0.00        NR          2.0          0.0
#
# ...

# %%
df = df[['hs_code', 'commodity', 'br_x_q', 'br_x_unit', 'py_m_q', 'py_m_unit', 'br_x_nt_wgt',
       'py_m_nt_wgt', 'br_x_value', 'itic_rate', 'applied_tariff',
       'adj_x_value', 'py_m_value', 'trade_gap', 'est_tax_loss', 'wgt_gap',
       'value_ratio', 'wgt_ratio', 'density']]

# %%
df
# Out:
#       hs_code                                          commodity  br_x_q  \
# 0       10310                           Pure-bred breeding swine   641.0
# 1       10310                           Pure-bred breeding swine   641.0
# 2       10310                           Pure-bred breeding swine   641.0
# 3       10392  Live pure-bred swine, weighing >= 50 kg (excl....   904.0
# 4       10392  Live pure-bred swine, weighing >= 50 kg (excl....   904.0
# ...       ...                                                ...     ...
# 9178   950632                                         Golf balls    22.0
# 9179   950632                                         Golf balls    22.0
# 9180   961320           Pocket lighters, gas fuelled, refillable    17.0
# 9181   961320           Pocket lighters, gas fuelled, refillable    17.0
# 9182   961320           Pocket lighters, gas fuelled, refillable    17.0
#
#      br_x_unit   py_m_q py_m_unit  br_x_nt_wgt  py_m_nt_wgt  br_x_value  \
# ...
