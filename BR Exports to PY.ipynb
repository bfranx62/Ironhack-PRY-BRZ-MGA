# %%
# import os

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
# os.getcwd()

# %%
df = pd.read_csv('brz_exports_to_pry.csv', encoding='unicode_escape')

# %%
df.head()
# Out:
#   TypeCode FreqCode  RefPeriodId  RefYear  RefMonth  Period  ReporterCode  \
# 0        C        A     20230101     2023        52    2023            76
# 1        C        A     20230101     2023        52    2023            76
# 2        C        A     20230101     2023        52    2023            76
# 3        C        A     20230101     2023        52    2023            76
# 4        C        A     20230101     2023        52    2023            76
#
#   ReporterISO ReporterDesc FlowCode  ... IsNetWgtEstimated  GrossWgt  \
# 0         BRA       Brazil        X  ...             False         0
# 1         BRA       Brazil        X  ...             False         0
# 2         BRA       Brazil        X  ...             False         0
# 3         BRA       Brazil        X  ...             False         0
# 4         BRA       Brazil        X  ...             False         0
#
#   IsGrossWgtEstimated Cifvalue  Fobvalue PrimaryValue LegacyEstimationFlag  \
# 0               False      NaN  12249277     12249277                    0
# 1               False      NaN     75081        75081                    0
# 2               False      NaN     75081        75081                    0
# 3               False      NaN    163801       163801                    0
# 4               False      NaN    163801       163801                    0
#
#   IsReported IsAggregate  Unnamed: 47
# 0      False        True          NaN
# 1      False        True          NaN
# 2      False        True          NaN
# 3      False        True          NaN
# 4      False        True          NaN
#
# [5 rows x 48 columns]

# %%
df = df.drop('TypeCode', axis=1)

# %%
df = df.drop('FreqCode', axis=1)
df = df.drop('RefPeriodId', axis=1)

# %%
df.head()
# Out:
#    RefYear  RefMonth  Period  ReporterCode ReporterISO ReporterDesc FlowCode  \
# 0     2023        52    2023            76         BRA       Brazil        X
# 1     2023        52    2023            76         BRA       Brazil        X
# 2     2023        52    2023            76         BRA       Brazil        X
# 3     2023        52    2023            76         BRA       Brazil        X
# 4     2023        52    2023            76         BRA       Brazil        X
#
#   FlowDesc  PartnerCode PartnerISO  ... IsNetWgtEstimated  GrossWgt  \
# 0   Export          600        PRY  ...             False         0
# 1   Export          600        PRY  ...             False         0
# 2   Export          600        PRY  ...             False         0
# 3   Export          600        PRY  ...             False         0
# 4   Export          600        PRY  ...             False         0
#
#   IsGrossWgtEstimated Cifvalue  Fobvalue PrimaryValue  LegacyEstimationFlag  \
# 0               False      NaN  12249277     12249277                     0
# 1               False      NaN     75081        75081                     0
# 2               False      NaN     75081        75081                     0
# 3               False      NaN    163801       163801                     0
# 4               False      NaN    163801       163801                     0
#
#   IsReported IsAggregate  Unnamed: 47
# 0      False        True          NaN
# 1      False        True          NaN
# 2      False        True          NaN
# 3      False        True          NaN
# 4      False        True          NaN
#
# [5 rows x 45 columns]

# %%
df = df.drop('RefMonth', axis=1)
df = df.drop('Period', axis=1)
df = df.drop('ReporterCode', axis=1)
df = df.drop('ReporterISO', axis=1)

# %%
df = df.drop('FlowCode', axis=1)
df = df.drop('PartnerCode', axis=1)
df = df.drop('PartnerISO', axis=1)

# %%
df.head()
# Out:
#    RefYear ReporterDesc FlowDesc PartnerDesc  Partner2Code Partner2ISO  \
# 0     2023       Brazil   Export    Paraguay             0         W00
# 1     2023       Brazil   Export    Paraguay             0         W00
# 2     2023       Brazil   Export    Paraguay             0         W00
# 3     2023       Brazil   Export    Paraguay             0         W00
# 4     2023       Brazil   Export    Paraguay             0         W00
#
#   Partner2Desc ClassificationCode ClassificationSearchCode  \
# 0        World                 H6                       HS
# 1        World                 H6                       HS
# 2        World                 H6                       HS
# 3        World                 H6                       HS
# 4        World                 H6                       HS
#
#    IsOriginalClassification  ... IsNetWgtEstimated GrossWgt  \
# 0                      True  ...             False        0
# 1                      True  ...             False        0
# 2                      True  ...             False        0
# 3                      True  ...             False        0
# 4                      True  ...             False        0
#
#    IsGrossWgtEstimated  Cifvalue  Fobvalue PrimaryValue  LegacyEstimationFlag  \
# 0                False       NaN  12249277     12249277                     0
# 1                False       NaN     75081        75081                     0
# 2                False       NaN     75081        75081                     0
# 3                False       NaN    163801       163801                     0
# 4                False       NaN    163801       163801                     0
#
#    IsReported IsAggregate  Unnamed: 47
# 0       False        True          NaN
# 1       False        True          NaN
# 2       False        True          NaN
# 3       False        True          NaN
# 4       False        True          NaN
#
# [5 rows x 38 columns]

# %%
df = df.drop('Partner2Code', axis=1)
df = df.drop('Partner2ISO', axis=1)
df = df.drop('Partner2Desc', axis=1)
df = df.drop('ClassificationCode', axis=1)
df = df.drop('ClassificationSearchCode', axis=1)
df = df.drop('IsOriginalClassification', axis=1)

# %%
df.head()
# Out:
#    RefYear ReporterDesc FlowDesc PartnerDesc CmdCode  \
# 0     2023       Brazil   Export    Paraguay      01
# 1     2023       Brazil   Export    Paraguay    0101
# 2     2023       Brazil   Export    Paraguay  010121
# 3     2023       Brazil   Export    Paraguay    0102
# 4     2023       Brazil   Export    Paraguay  010221
#
#                                     CmdDesc  AggrLevel  IsLeaf CustomsCode  \
# 0                             Animals; live          2   False         C00
# 1    Horses, asses, mules and hinnies; live          4   False         C00
# 2  Horses; live, pure-bred breeding animals          6    True         C00
# 3                      Bovine animals; live          4   False         C00
# 4  Cattle; live, pure-bred breeding animals          6    True         C00
#
#   CustomsDesc  ...  IsNetWgtEstimated  GrossWgt IsGrossWgtEstimated  Cifvalue  \
# 0   TOTAL CPC  ...              False         0               False       NaN
# 1   TOTAL CPC  ...              False         0               False       NaN
# 2   TOTAL CPC  ...              False         0               False       NaN
# 3   TOTAL CPC  ...              False         0               False       NaN
# 4   TOTAL CPC  ...              False         0               False       NaN
#
#    Fobvalue  PrimaryValue  LegacyEstimationFlag  IsReported IsAggregate  \
# 0  12249277      12249277                     0       False        True
# 1     75081         75081                     0       False        True
# 2     75081         75081                     0       False        True
# 3    163801        163801                     0       False        True
# 4    163801        163801                     0       False        True
#
#    Unnamed: 47
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 32 columns]

# %%
df = df.drop('IsLeaf', axis=1)
df = df.drop('CustomsCode', axis=1)
df = df.drop('CustomsDesc', axis=1)
df = df.drop('IsNetWgtEstimated', axis=1)
df = df.drop('GrossWgt', axis=1)
df = df.drop('IsGrossWgtEstimated', axis=1)

# %%
df.head()
# Out:
#    RefYear ReporterDesc FlowDesc PartnerDesc CmdCode  \
# 0     2023       Brazil   Export    Paraguay      01
# 1     2023       Brazil   Export    Paraguay    0101
# 2     2023       Brazil   Export    Paraguay  010121
# 3     2023       Brazil   Export    Paraguay    0102
# 4     2023       Brazil   Export    Paraguay  010221
#
#                                     CmdDesc  AggrLevel  MosCode  MotCode  \
# 0                             Animals; live          2        0        0
# 1    Horses, asses, mules and hinnies; live          4        0        0
# 2  Horses; live, pure-bred breeding animals          6        0        0
# 3                      Bovine animals; live          4        0        0
# 4  Cattle; live, pure-bred breeding animals          6        0        0
#
#      MotDesc  ...  AltQty IsAltQtyEstimated   NetWgt  Cifvalue  Fobvalue  \
# 0  TOTAL MOT  ...       0             False      0.0       NaN  12249277
# 1  TOTAL MOT  ...      17             False   8200.0       NaN     75081
# 2  TOTAL MOT  ...      17             False   8200.0       NaN     75081
# 3  TOTAL MOT  ...      17             False  10937.0       NaN    163801
# 4  TOTAL MOT  ...      17             False  10937.0       NaN    163801
#
#   PrimaryValue  LegacyEstimationFlag  IsReported  IsAggregate  Unnamed: 47
# 0     12249277                     0       False         True          NaN
# 1        75081                     0       False         True          NaN
# 2        75081                     0       False         True          NaN
# 3       163801                     0       False         True          NaN
# 4       163801                     0       False         True          NaN
#
# [5 rows x 26 columns]

# %%
df = df.drop('MosCode', axis=1)
df = df.drop('MotCode', axis=1)
df = df.drop('MotDesc', axis=1)
df = df.drop('AltQty', axis=1)
df = df.drop('IsAltQtyEstimated', axis=1)
df = df.drop('PrimaryValue', axis=1)

# %%
df.head()
# Out:
#    RefYear ReporterDesc FlowDesc PartnerDesc CmdCode  \
# 0     2023       Brazil   Export    Paraguay      01
# 1     2023       Brazil   Export    Paraguay    0101
# 2     2023       Brazil   Export    Paraguay  010121
# 3     2023       Brazil   Export    Paraguay    0102
# 4     2023       Brazil   Export    Paraguay  010221
#
#                                     CmdDesc  AggrLevel  QtyUnitCode  \
# 0                             Animals; live          2           -1
# 1    Horses, asses, mules and hinnies; live          4            5
# 2  Horses; live, pure-bred breeding animals          6            5
# 3                      Bovine animals; live          4            5
# 4  Cattle; live, pure-bred breeding animals          6            5
#
#   QtyUnitAbbr   Qty  IsQtyEstimated  AltQtyUnitCode AltQtyUnitAbbr   NetWgt  \
# 0         NaN   0.0           False              -1            NaN      0.0
# 1           u  17.0           False               5              u   8200.0
# 2           u  17.0           False               5              u   8200.0
# 3           u  17.0           False               5              u  10937.0
# 4           u  17.0           False               5              u  10937.0
#
#    Cifvalue  Fobvalue  LegacyEstimationFlag  IsReported  IsAggregate  \
# 0       NaN  12249277                     0       False         True
# 1       NaN     75081                     0       False         True
# 2       NaN     75081                     0       False         True
# 3       NaN    163801                     0       False         True
# 4       NaN    163801                     0       False         True
#
#    Unnamed: 47
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
df = df.drop('QtyUnitCode', axis=1)
df = df.drop('AltQtyUnitCode', axis=1)
df = df.drop('IsQtyEstimated', axis=1)

# %%
df = df.drop('AltQtyUnitAbbr', axis=1)
df = df.drop('LegacyEstimationFlag', axis=1)
df = df.drop('IsReported', axis=1)
df = df.drop('IsAggregate', axis=1)

# %%
df.head()
# Out:
#    RefYear ReporterDesc FlowDesc PartnerDesc CmdCode  \
# 0     2023       Brazil   Export    Paraguay      01
# 1     2023       Brazil   Export    Paraguay    0101
# 2     2023       Brazil   Export    Paraguay  010121
# 3     2023       Brazil   Export    Paraguay    0102
# 4     2023       Brazil   Export    Paraguay  010221
#
#                                     CmdDesc  AggrLevel QtyUnitAbbr   Qty  \
# 0                             Animals; live          2         NaN   0.0
# 1    Horses, asses, mules and hinnies; live          4           u  17.0
# 2  Horses; live, pure-bred breeding animals          6           u  17.0
# 3                      Bovine animals; live          4           u  17.0
# 4  Cattle; live, pure-bred breeding animals          6           u  17.0
#
#     NetWgt  Cifvalue  Fobvalue  Unnamed: 47
# 0      0.0       NaN  12249277          NaN
# 1   8200.0       NaN     75081          NaN
# 2   8200.0       NaN     75081          NaN
# 3  10937.0       NaN    163801          NaN
# 4  10937.0       NaN    163801          NaN

# %%
df = df.drop('Unnamed: 47', axis=1)

# %%
df = df.rename(columns={'RefYear':'year', 'ReporterDesc':'reporter','FlowDesc':'trade_flow','PartnerDesc':'partner','CmdCode':'hs_code','CmdDesc':'commodity', 'QtyUnitAbbr':'unit_type','Qty':'quantity','NetWgt':'net_weight','Cifvalue':'cif_value','Fobvalue':'fob_value'})

# %%
df = df[df['AggrLevel']==6]

# %%
df = df.drop(columns = 'AggrLevel')

# %%
df.head()
# Out:
#    year reporter trade_flow   partner hs_code  \
# 2  2023   Brazil     Export  Paraguay  010121
# 4  2023   Brazil     Export  Paraguay  010221
# 6  2023   Brazil     Export  Paraguay  010310
# 7  2023   Brazil     Export  Paraguay  010392
# 9  2023   Brazil     Export  Paraguay  010511
#
#                                            commodity unit_type    quantity  \
# 2           Horses; live, pure-bred breeding animals         u        17.0
# 4           Cattle; live, pure-bred breeding animals         u        17.0
# 6            Swine; live, pure-bred breeding animals         u       641.0
# 7  Swine; live, other than pure-bred breeding ani...         u       904.0
# 9  Poultry; live, fowls of the species Gallus dom...         u  13417432.0
#
#    net_weight  cif_value  fob_value
# 2      8200.0        NaN      75081
# 4     10937.0        NaN     163801
# 6     58244.0        NaN     649041
# 7     79649.0        NaN     579106
# 9    642645.0        NaN   10782248

# %%
df.shape
# Out:
# (3306, 11)

# %%
df['trade_flow']=df['trade_flow'].replace('Export','exported_to')

# %%
df.dtypes
# Out:
# year            int64
# reporter       object
# trade_flow     object
# partner        object
# hs_code        object
# commodity      object
# unit_type      object
# quantity      float64
# net_weight    float64
# cif_value     float64
# fob_value       int64
# dtype: object

# %%
df.head()
# Out:
#    year reporter   trade_flow   partner hs_code  \
# 2  2023   Brazil  exported_to  Paraguay  010121
# 4  2023   Brazil  exported_to  Paraguay  010221
# 6  2023   Brazil  exported_to  Paraguay  010310
# 7  2023   Brazil  exported_to  Paraguay  010392
# 9  2023   Brazil  exported_to  Paraguay  010511
#
#                                            commodity unit_type    quantity  \
# 2           Horses; live, pure-bred breeding animals         u        17.0
# 4           Cattle; live, pure-bred breeding animals         u        17.0
# 6            Swine; live, pure-bred breeding animals         u       641.0
# 7  Swine; live, other than pure-bred breeding ani...         u       904.0
# 9  Poultry; live, fowls of the species Gallus dom...         u  13417432.0
#
#    net_weight  cif_value  fob_value
# 2      8200.0        NaN      75081
# 4     10937.0        NaN     163801
# 6     58244.0        NaN     649041
# 7     79649.0        NaN     579106
# 9    642645.0        NaN   10782248

# %%
df['unit_type'].value_counts()
# Out:
# unit_type
# kg              2400
# u                799
# m²                31
# l                 21
# 2u                21
# m³                13
# 1000u              1
# U (jeu/pack)       1
# Name: count, dtype: int64

# %%
df['unit_type']=df['unit_type'].replace(['1000u','thousands_of_units'],['2u','pairs_of_units'])

# %%
df['unit_type']=df['unit_type'].replace(['l','liters'],['m²','square_meters'])

# %%
df['unit_type']=df['unit_type'].replace(['m³','cubic_meters'],['u','units'])

# %%
df.head()
# Out:
#    year reporter   trade_flow   partner hs_code  \
# 2  2023   Brazil  exported_to  Paraguay  010121
# 4  2023   Brazil  exported_to  Paraguay  010221
# 6  2023   Brazil  exported_to  Paraguay  010310
# 7  2023   Brazil  exported_to  Paraguay  010392
# 9  2023   Brazil  exported_to  Paraguay  010511
#
#                                            commodity unit_type    quantity  \
# 2           Horses; live, pure-bred breeding animals         u        17.0
# 4           Cattle; live, pure-bred breeding animals         u        17.0
# 6            Swine; live, pure-bred breeding animals         u       641.0
# 7  Swine; live, other than pure-bred breeding ani...         u       904.0
# 9  Poultry; live, fowls of the species Gallus dom...         u  13417432.0
#
#    net_weight  cif_value  fob_value
# 2      8200.0        NaN      75081
# 4     10937.0        NaN     163801
# 6     58244.0        NaN     649041
# 7     79649.0        NaN     579106
# 9    642645.0        NaN   10782248

# %%
df.isnull().sum()

#interesting to see that both exports don't have any cif values at all
# Out:
# year             0
# reporter         0
# trade_flow       0
# partner          0
# hs_code          0
# commodity        0
# unit_type       19
# quantity         0
# net_weight       8
# cif_value     3306
# fob_value        0
# dtype: int64

# %%
df[df['net_weight'].isnull()]
# Out:
#       year reporter   trade_flow   partner hs_code  \
# 74    2023   Brazil  exported_to  Paraguay  060290
# 919   2023   Brazil  exported_to  Paraguay  293391
# 947   2023   Brazil  exported_to  Paraguay  293969
# 1375  2023   Brazil  exported_to  Paraguay  392093
# 1472  2023   Brazil  exported_to  Paraguay  401310
# 2710  2023   Brazil  exported_to  Paraguay  720926
# 2798  2023   Brazil  exported_to  Paraguay  722830
# 3913  2023   Brazil  exported_to  Paraguay  854099
#
#                                               commodity unit_type  quantity  \
# 74             Plants, live; n.e.c. in heading no. 0602       NaN       0.0
# 919   Heterocyclic compounds; alprazolam (INN), cama...       NaN       0.0
# 947   Alkaloids; of rye ergot and their derivatives,...       NaN       0.0
# 1375  Plastics; plates, sheets, film, foil and strip...       NaN       0.0
# 1472  Rubber; inner tubes, of a kind used on motorca...         u   18924.0
# 2710  Iron or non-alloy steel; (not in coils), flat-...       NaN       0.0
# 2798  Steel, alloy; bars and rods, hot-rolled, hot-d...       NaN       0.0
# 3913  Valves and tubes; parts of the valves and tube...       NaN       0.0
#
#       net_weight  cif_value  fob_value
# 74           NaN        NaN      25684
# 919          NaN        NaN         10
# 947          NaN        NaN        145
# 1375         NaN        NaN         44
# 1472         NaN        NaN     245753
# 2710         NaN        NaN      75944
# 2798         NaN        NaN     164785
# 3913         NaN        NaN        152

# %%
df=df.drop('cif_value',axis=1)

# %%
df.to_csv('cleaned br exports to py.csv',index=False)

# %%
# Saves data from new .csv file as newdf to ensure that everything worked. 
newdf = pd.read_csv('cleaned br exports to py.csv')
newdf
# Out:
#       year reporter   trade_flow   partner  hs_code  \
# 0     2023   Brazil  exported_to  Paraguay    10121
# 1     2023   Brazil  exported_to  Paraguay    10221
# 2     2023   Brazil  exported_to  Paraguay    10310
# 3     2023   Brazil  exported_to  Paraguay    10392
# 4     2023   Brazil  exported_to  Paraguay    10511
# ...    ...      ...          ...       ...      ...
# 3301  2023   Brazil  exported_to  Paraguay   962000
# 3302  2023   Brazil  exported_to  Paraguay   970121
# 3303  2023   Brazil  exported_to  Paraguay   970191
# 3304  2023   Brazil  exported_to  Paraguay   970199
# 3305  2023   Brazil  exported_to  Paraguay   999999
#
#                                               commodity unit_type    quantity  \
# 0              Horses; live, pure-bred breeding animals         u        17.0
# 1              Cattle; live, pure-bred breeding animals         u        17.0
# 2               Swine; live, pure-bred breeding animals         u       641.0
# 3     Swine; live, other than pure-bred breeding ani...         u       904.0
# 4     Poultry; live, fowls of the species Gallus dom...         u  13417432.0
# ...                                                 ...       ...         ...
# 3301     Monopods, bipods, tripods and similar articles        kg        14.0
# 3302  Paintings, drawings and pastels; executed enti...         u       289.0
# 3303  Paintings, drawings and pastels; executed enti...         u        16.0
# 3304  Artwork; other than paintings, drawings, paste...        kg        67.0
# 3305        Commodities not specified according to kind       NaN         0.0
#
#       net_weight  fob_value
# 0         8200.0      75081
# 1        10937.0     163801
# 2        58244.0     649041
# 3        79649.0     579106
# 4       642645.0   10782248
# ...          ...        ...
# 3301        14.0        299
# 3302      2598.0      38696
# 3303        32.0        167
# 3304        67.0       3667
# 3305         0.0        529
#
# [3306 rows x 10 columns]
